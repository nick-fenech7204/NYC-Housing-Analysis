# %%
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt

# %%
server = "cohort50sqlserver.database.windows.net" 
database = 'Illidans_Ingenious_Infrastructure' 
username = 'tripleI' 
password = 'PA55W0RD!'  
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
query = "SELECT * FROM dbo.boroughs_housing;"
df = pd.read_sql(query, cnxn)
# df.head()
# Out:
#   BOROUGH               NEIGHBORHOOD  \
# 0       1  LITTLE ITALY
# 1       1  ALPHABET CITY
# 2       1  GREENWICH VILLAGE-CENTRAL
# 3       1  MIDTOWN WEST
# 4       1  LITTLE ITALY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT BLOCK  \
# 0  13  CONDOS - ELEVATOR APARTMENTS                                2   478
# 1  02  TWO FAMILY HOMES                                            1   375
# 2  10  COOPS - ELEVATOR APARTMENTS                                2C   552
# 3  13  CONDOS - ELEVATOR APARTMENTS                                2  1011
# 4  13  CONDOS - ELEVATOR APARTMENTS                                2   492
#
#     LOT ZIP CODE RESIDENTIAL UNITS COMMERCIAL UNITS TOTAL UNITS  \
# 0  1040    10013                 1                0           1
# 1    32    10009                 2                0           2
# 2    64    10011                 0                0           0
# 3  4265    10019                 1                0           1
# ...

# %%
training_data = df.loc[(df['SALE DATE'] < '2022-01-01')]
training_data
# Out:
#         BOROUGH               NEIGHBORHOOD  \
# 0             1  LITTLE ITALY
# 1             1  ALPHABET CITY
# 2             1  GREENWICH VILLAGE-CENTRAL
# 3             1  MIDTOWN WEST
# 4             1  LITTLE ITALY
# ...         ...                        ...
# 1089920       5                  ROSSVILLE
# 1089921       5                  ROSSVILLE
# 1089922       5                  ROSSVILLE
# 1089923       5                  ROSSVILLE
# 1089924       5                  ROSSVILLE
#
#                               BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0        13  CONDOS - ELEVATOR APARTMENTS                                2
# 1        02  TWO FAMILY HOMES                                            1
# 2        10  COOPS - ELEVATOR APARTMENTS                                2C
# 3        13  CONDOS - ELEVATOR APARTMENTS                                2
# 4        13  CONDOS - ELEVATOR APARTMENTS                                2
# ...

# %%
boroughs2022 = df.loc[(df['SALE DATE'] >= '2022-01-01')]
boroughs2022.reset_index(drop=True,inplace=True)
boroughs2022
# Out:
#       BOROUGH             NEIGHBORHOOD     BUILDING CLASS CATEGORY  \
# 0           1  UPPER EAST SIDE (79-96)     01 ONE FAMILY DWELLINGS
# 1           1  UPPER EAST SIDE (79-96)     01 ONE FAMILY DWELLINGS
# 2           1  UPPER EAST SIDE (79-96)     01 ONE FAMILY DWELLINGS
# 3           1  UPPER EAST SIDE (79-96)     01 ONE FAMILY DWELLINGS
# 4           1  UPPER EAST SIDE (79-96)     01 ONE FAMILY DWELLINGS
# ...       ...                      ...                         ...
# 29592       5            MIDLAND BEACH  05 TAX CLASS 1 VACANT LAND
# 29593       5            MIDLAND BEACH  05 TAX CLASS 1 VACANT LAND
# 29594       5            MIDLAND BEACH  05 TAX CLASS 1 VACANT LAND
# 29595       5            MIDLAND BEACH  05 TAX CLASS 1 VACANT LAND
# 29596       5            MIDLAND BEACH  05 TAX CLASS 1 VACANT LAND
#
#       TAX CLASS AT PRESENT BLOCK  LOT ZIP CODE RESIDENTIAL UNITS  \
# 0                        1  1505   30    10128                 1
# ...
